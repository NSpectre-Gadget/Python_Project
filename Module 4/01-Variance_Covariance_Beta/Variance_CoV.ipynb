# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
daily_returns_amzn_spx=pd.read_csv(Path("amzn_sp500_data.csv"), index_col='date', parse_dates=True, infer_datetime_format=True)

# %%
daily_returns_amzn_spx.pct_change().dropna()
# Out:
#                 AMZN   S&P 500
# date
# 2014-05-21  0.012683  0.008116
# 2014-05-22 -0.000328  0.002362
# 2014-05-23  0.024040  0.004248
# 2014-05-27 -0.004548  0.005988
# 2014-05-28 -0.002123 -0.001114
# ...              ...       ...
# 2019-05-13 -0.035609 -0.024131
# 2019-05-14  0.009568  0.008016
# 2019-05-15  0.016863  0.005839
# 2019-05-16  0.019464  0.008895
# 2019-05-17 -0.020219 -0.005837
#
# [1257 rows x 2 columns]

# %%
# Plotting the daily returns for Amazon and the S&P 500
daily_returns_amzn_spx.plot(figsize=(10, 7), title="Daily Returns - Amazon & S&P 500")
# Out:
# <AxesSubplot:title={'center':'Daily Returns - Amazon & S&P 500'}, xlabel='date'>

# %%
# Using the Pandas 'var' function, calculate the variance of AMZN and the S&P 500
daily_returns_amzn_spx.var()
# Out:
# AMZN       264128.876702
# S&P 500    102061.544922
# dtype: float64

# %%
import pandas as pd

stocks = pd.DataFrame({
'stock_hij' : [142.13, 143.54, 142.52, 143.43, 141.73, 137.68, 139.71, 139.60, 139.61, 141.57],
'stock_klm' : [53.88, 52.83, 52.55, 53.84, 54.16, 55.58, 53.43, 52.50, 53.90, 47.86],
'market' : [3534.22, 3511.93, 3488.67, 3483.34, 3483.81, 3426.92, 3443.12, 3435.56, 3453.49, 3449.52]
})

# %%
stocks.pct_change().dropna()
# Out:
#    stock_hij  stock_klm    market
# 1   0.009920  -0.019488 -0.006307
# 2  -0.007106  -0.005300 -0.006623
# 3   0.006385   0.024548 -0.001528
# 4  -0.011852   0.005944  0.000135
# 5  -0.028575   0.026219 -0.016330
# 6   0.014744  -0.038683  0.004727
# 7  -0.000787  -0.017406 -0.002196
# 8   0.000072   0.026667  0.005219
# 9   0.014039  -0.112059 -0.001150

# %%
stocks.plot(figsize=(10,7), title="Daily Returns")
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}>

# %%
stocks.var()
# Out:
# stock_hij       3.683240
# stock_klm       4.149979
# market       1227.213907
# dtype: float64

# %%
import pandas as pd

stocks = pd.DataFrame({
'stock_hij' : [142.13, 143.54, 142.52, 143.43, 141.73, 137.68, 139.71, 139.60, 139.61, 141.57],
'stock_klm' : [53.88, 52.83, 52.55, 53.84, 54.16, 55.58, 53.43, 52.50, 53.90, 47.86],
'market' : [3534.22, 3511.93, 3488.67, 3483.34, 3483.81, 3426.92, 3443.12, 3435.56, 3453.49, 3449.52]
})

# %%
daily_returns_df=stocks.pct_change().dropna()

# %%
covariance = daily_returns_df['stock_hij'].cov(daily_returns_df['stock_klm'])
print(f"{covariance: .8f}")
# Out:
# -0.00037313

# %%
covariance = daily_returns_df['stock_hij'].cov(daily_returns_df['market'])
print(f"{covariance: .8f}")
# Out:
#  0.00006087

# %%
covariance = daily_returns_df['stock_klm'].cov(daily_returns_df['market'])
print(f"the covariance is:{covariance: .8f}")
# Out:
# the covariance is:-0.00005954
